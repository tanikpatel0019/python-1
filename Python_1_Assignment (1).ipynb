# %% [markdown]
# Python 1
#
# 1.What is python, why it is popular?
#  - Python is high level programming langauge.
#  - easy to learn.
#  - widely use in industry.
#  - python has lot of libraries.
#  - huge active community.
#
# 3.what are pre-define in python?
#  - pre-define word that hold a special meaning and have specific purpose in    python programming.
#
# 4.can keyword use in variable name?
# - No, keyword can not be use in variable name in python.
#
# 5.what is mutability in python?
# - object or countainer whose state or value can be changed after they created mutability.
#
# 7.what is difference between "==" and "is" operators in python?
# - "==" compare tow value
# - "is" compares the location of two object or varible.
#
# 8.what are logical operators in python?
# - logical operator are used to combine boolean expression and return a boolean value.
#
# 9.what is type casting?
# - the process of changing the data type of a value/object.
#
# 11.what is purpose of conditional statement work?
# - the purpose of conditional satement in python is allow the program to make dicision and execute different blocks of code based on specific condition.
#
# 12.How dose the elif statement work?
# - python check first "if" condition.
# - if it's true, it execute that the block and skip the rest.
# - if it's false, it checks the elif conditions.
# - multiple elif blocks.
# - if none of the if oe elif conditions are true the else block is executed.

# %%
#1.write a python program to print "Hello, World!"
print("Hello World!")
# Out:
# Hello World!

# %%
#2.write a python program that display your name and age.
name = print("Tanik")
age = print("22")
# Out:
# Tanik
# 22

# %%
#3.write code to print all the pre-define keyword in python using the keyword library.
help('keyword')
# Out:
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "Grammar/python.gram")
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/keyword.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This file is automatically generated; please don't muck it up!
#
#     To update the symbols in this file, 'cd' to the top directory of
#     the python source tree and run:
#
#         PYTHONPATH=Tools/peg_generator python3 -m pegen.keywordgen         Grammar/python.gram         Grammar/Tokens         Lib/keyword.py
#
#     Alternatively, you can run 'make regen-keyword'.
#
# FUNCTIONS
#     iskeyword = __contains__(...) method of builtins.frozenset instance
# ...

# %%
#4.write a program that checks if a given word is a python keyword.
name = ("Python keyword")
if name == "Python keyword":
  print('t')
else:
  print('f')
# Out:
# t

# %%
#5.create a list and tuple in python, and demonstrate how attempting to change on element works differently for each.
list = [1,2,3]
list[0] = 100
print("list",list)
# Out:
# list [100, 2, 3]

# %%
#tuple
tuple = (1,2,3)
try:
  tuple[0] = 100
except TypeError:
  print("can't change a tuple")
# Out:
# can't change a tuple

# %%
#6.write a function to demonstrate the behavior of mutable and imutable arguments.

# %%
#7.write a program that performs basic arithmetic operations on two user-input number.
#addition
num1 = float(input("Enter the first number"))
num2 = float(input("Enter the secound number"))
print(num1 + num2)
# Out:
# Enter the first number5
# Enter the secound number4
# 9.0

# %%
#subtraction
num1 = float(input("Enter the first number"))
num2 = float(input("Enter the secound number"))
print(num1 - num2)
# Out:
# Enter the first number50
# Enter the secound number20
# 30.0

# %%
#multiplication
num1 = float(input("Enter the first number"))
num2 = float(input("Enter the secound number"))
print(num1 * num2)
# Out:
# Enter the first number20
# Enter the secound number10
# 200.0

# %%
#8.write a program to demonstrate the use of logical operators.
a = 6
b = 50
print(a > 0 and b > 0)
# Out:
# True

# %%
#9.write a python program to convert user input from string to integer, float, and boolem types.
#string to integer
a = input("Enter a number")
type(int(a))
# Out:
# Enter a number5
# int

# %%
#string to float
a = input("Enter a number")
type(float(a))
# Out:
# Enter a number58
# float

# %%
#string to boolem
a = input("Enter a number")
type(bool(a))
# Out:
# Enter a number78
# bool

# %%
#10.write code demonstrate type casting with list elements.

# %%
#11.write a program that checks if number is positive, negetive, or zero.
num = float(input("Enter a number"))
if num > 5:
  print("the number is positive")
elif num < 5:
  print("the number is negative")
else:
  print("the number is zero")
# Out:
# Enter a number56
# the number is positive

# %%
#12.write a for loop to print number from 1 to 100.
for i in range(1,10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#13.write python program to find the sum of all even numbers between 1 and 50.
even_num = 0
for i in range(1,51):
  if i % 2 == 0:
    even_num += i
    print(even_num)
# Out:
# 2
# 6
# 12
# 20
# 30
# 42
# 56
# 72
# 90
# 110
# 132
# 156
# 182
# 210
# 240
# 272
# 306
# 342
# 380
# 420
# 462
# 506
# 552
# 600
# 650

# %%
#14.write a program to reverse a string using a while loop.

# %%
#15.write a python program to calculate te factorial of a number provided by the user a while loop.
