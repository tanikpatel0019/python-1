# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
# - 1. Compiled Language
#    - A compiled language is one where the source code is translated into machine code before running.
#    - Fast Execution
#    - Optimized by the compiler for performance.
#   2. interpreted Langauge
#    - An interpreted language is one where the source code is read and executed line by line by an interpreter program at runtime.
#    - Easier and faster to test and debug.
#    - Portable
#
# 2. What is exception handling in Python?
# - An exception is an error that happens while the program is running.
#
# 3. What is the purpose of the finally block in exception handling?
# - It ensures cleanup actions are always performed
# Runs after the try and except blocks finish.
# Executes whether:
# An exception was raised,
# No exception was raised, or
# An exception was not handled.
#
# 4. What is logging in Python ?
# - Logging is like a “black box recorder” for your Python program — it keeps track of what happened, when, and how serious it was.
#
# 5. What is the significance of the __del__ method in Python?
# - The __de__ method is significant because it lets you perform cleanup before an object is destroyed, but it should be used with caution. For most real-world cases, context managers are safer.
#
# 6. What is the difference between import and from ... import in Python ?
# - 1. import Statement
#    - Imports the whole module.
#    - You must use the module name to access its functions, classes, or variables.
#   2. from ... import Statement
#    - Imports specific attributes from a module.
#    - You can use them directly without the module prefix.
#
# 7. How can you handle multiple exceptions in Python ?
# - Use separate except blocks if you need different handling for each error.
# - Use a tuple of exceptions if the handling is the same.
# - Use Exception as e if you want to catch all errors and inspect them.
#
# 8. What is the purpose of the with statement when handling files in Python ?
# - The with statement ensures safe and automatic cleanup of files (and other resources), making your code more reliable and concise.
#
# 9. What is the difference between multithreading and multiprocessing ?
# - Multithreading
#   - Multiple threads run inside the same process.
#   - Threads share the same memory space.
# - Multiprocessing
#   - Multiple processes run in parallel, each with its own memory space and Python interpreter.
#   - Processes do not share memory.
#
# 10. What are the advantages of using logging in a program ?
# - Better Debugging & Monitoring
# - Different Log Levels
# - Persistent Logs
# - Configurability
# - Non-intrusive
# - Useful in Production
# - Thread & Process Safe
#
# 11. What is memory management in Python ?
# - Memory management in Python is the process of allocating and deallocating memory for objects so programs can run efficiently without wasting memory.
# Python handles this automatically through its built-in memory manager and garbage collector, so developers usually don’t need to manage memory manually.
#
# 12. What are the basic steps involved in exception handling in Python ?
# - The basic steps in Python exception handling are:
#   - try → test risky code
#   - except → handle errors
#   - else → run if no errors
#   - finally → cleanup, always runs
#
# 13. Why is memory management important in Python ?
# - Memory management is important in Python because it:
#    - Saves resources,
#    - Prevents memory leaks,
#    - Improves performance,
#    - Makes programs safe and reliable,
#    - Allows developers to focus on logic instead of manual memory handling.
#
# 14. What is the role of try and except in exception handling ?
# - try = Test a block of code for errors.
# - except = Handle the error if it occurs, preventing program crash.
#
# 15. How does Python's garbage collection system work ?
# - Using reference counting to free objects when no variables refer to them.
# - Using a cyclic garbage collector to detect and remove objects involved in circular references.
#
# 16. What is the purpose of the else block in exception handling ?
# - Run code only when no exception occurs,
# Keep code cleaner by separating normal execution from error handling.
#
# 17. What are the common logging levels in Python ?
# - DEBUG
# - INFO
# - WARNING
# - ERROR
# - CRITICAL
#
# 18. What is the difference between os.fork() and multiprocessing in Python ?
# - os.fork() for low-level Unix process management.
# - multiprocessing for portable, easier, and safer parallel programming in Python.
#
# 19. What is the importance of closing a file in Python ?
# - Releases Syatem Resources
# - Ensure Data is Written
# - Avoids File Corruption
# - Prevents Conflicts in Multi-User or Multi-Process Enviroments
# - Best Practice & Cleaner Code
#
# 20. What is the difference between file.read() and file.readline() in Python ?
# - file.read()
#   - Reads the entire contents of the file (or a specified number of bytes)
#   - A string containing all the data read
#   - Useful when you want to read the whole file at once
#   - Can be memory-intensive for large files because it loads the whole content
# - file.readline()
#   - Reads one line at a time from the file
#   - A string containing the next line, including the newline character \n
#   - Useful for processing files line by line, especially large files
#   - More memory-efficient for large files because it reads one line at a time
#
# 21. What is the logging module in Python used for ?
# - The logging module in Python is used for tracking events and messages that happen while a program runs. It provides a flexible framework to record messages about a program’s execution, which is useful for debugging, monitoring, and troubleshooting.
#
# 22. What is the os module in Python used for in file handling ?
# - The os module in Python is used for interacting with the operating system, and in the context of file handling, it provides a set of functions to perform operations on files and directories beyond simple reading and writing.
#
# 23. What are the challenges associated with memory management in Python ?
# - Circular References
# - Large Object Handling
# - Fragmentation
# - Memory Leaks
# - Garbage Collection Overhead
# - Inefficient Use of Memory
#
# 24. How do you raise an exception manually in Python ?
# - In Python, you can raise an exception manually using the raise statement. This is useful when you want to signal that an error or unexpected situation has occurred in your program.
#
# 25. Why is it important to use multithreading in certain applications ?
# - Improvers Performance for I/O-Bond Tasks
# - Enhances Responsiveness
# - Simplifies Program Structure
# - Resource Latency
# - Resource Sharing

# %%
#1. How can you open a file for writing in Python and write a string to it ?
file = open("example.txt", "w")
file.write("Hello, this is a test string.\n")
file.write("Writing another line.")
# Out:
# 21

# %%
#2. Write a Python program to read the contents of a file and print each line ?
with open("example.txt", "r") as file:
    lines = file.readlines()
    for line in lines:
        print(line.rstrip())
# Out:
# Hello, this is a test string.
# Writing another line.

# %%
#3. How would you handle a case where the file doesn't exist while trying to open it for reading ?
try:
    with open("example.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("File not found. Creating a new file...")
    with open("example.txt", "w") as file:
        file.write("This is a new file.")
# Out:
# Hello, this is a test string.
# Writing another line.

# %%
#4. Write a Python script that reads from one file and writes its content to another file ?

with open("source.txt", "w") as src_file:
    src_file.write("This is the content of the source file.")

with open("source.txt", "r") as src_file:
    content = src_file.read()
with open("destination.txt", "w") as dest_file:
    dest_file.write(content)

print("Content copied successfully from source.txt to destination.txt")
# Out:
# Content copied successfully from source.txt to destination.txt

# %%
#5. How would you catch and handle division by zero error in Python ?

try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
# Out:
# Error: Cannot divide by zero.

# %%
#6. Write a Python program that logs an error message to a log file when a division by zero exception occurs ?

import logging
logging.basicConfig(
    filename="error.log",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def divide(a, b):
    try:
        return a / b
    except ZeroDivisionError as e:
        logging.error("Division by zero error: %s", e)
        print("Error: Cannot divide by zero.")

divide(10, 0)
divide(20, 5)
# Out:
# ERROR:root:Division by zero error: division by zero
# Error: Cannot divide by zero.
# 4.0

# %%
#7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module ?

import logging

logging.basicConfig(
    filename="app.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
#8. Write a program to handle a file opening error using exception handling ?

try:

    with open("example.txt", "r") as file:
        content = file.read()
        print("File content:")
        print(content)
except FileNotFoundError:
    print("Error: The file does not exist.")
except PermissionError:
    print("Error: You do not have permission to access this file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# File content:
# Hello, this is a test string.
# Writing another line.

# %%
#9. How can you read a file line by line and store its content in a list in Python ?

lines_list = []
with open("example.txt", "r") as file:
    for line in file:
        lines_list.append(line.rstrip())

print(lines_list)
# Out:
# ['Hello, this is a test string.', 'Writing another line.']

# %%
#10. How can you append data to an existing file in Python ?

with open("example.txt", "a") as file:
    file.write("This is a new line.\n")
    file.write("Appending another line.\n")

print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
#11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

my_dict = {"name": "Alice", "age": 25}
try:
    print("City:", my_dict["city"])
except KeyError:
    print("Error: The key 'city' does not exist in the dictionary.")
# Out:
# Error: The key 'city' does not exist in the dictionary.

# %%
#12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions ?

try:
    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))
    result = num1 / num2
    print("Result:", result)
    my_dict = {"name": "Alice"}
    print("Age:", my_dict["age"])
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except ValueError:
    print("Error: Invalid input. Please enter a number.")
except KeyError as e:
    print(f"Error: Missing key {e} in the dictionary.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter numerator: 25
# Enter denominator: 5
# Result: 5.0
# Error: Missing key 'age' in the dictionary.

# %%
#13. How would you check if a file exists before attempting to read it in Python ?

import os
file_path = "example.txt"
if os.path.exists(file_path):
    with open(file_path, "r") as file:
        content = file.read()
        print(content)
else:
    print(f"Error: '{file_path}' does not exist.")
# Out:
# Hello, this is a test string.
# Writing another line.This is a new line.
# Appending another line.

# %%
#14. Write a program that uses the logging module to log both informational and error messages.

import logging
logging.basicConfig(
    filename="app.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logging.info("Program started successfully.")
try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
    logging.info(f"Division result: {result}")
except ZeroDivisionError as e:
    logging.error(f"An error occurred: {e}")

logging.info("Program finished.")
# Out:
# ERROR:root:An error occurred: division by zero

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty ?

file_path = "example.txt"

try:
    with open(file_path, "r") as file:
        content = file.read()
        if content:
            print("File content:")
            print(content)
        else:
            print("The file is empty.")
except FileNotFoundError:
    print(f"Error: '{file_path}' does not exist.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# File content:
# Hello, this is a test string.
# Writing another line.This is a new line.
# Appending another line.

# %%
#16. Demonstrate how to use memory profiling to check the memory usage of a small program ?
#pip install memory-profiler
from memory_profiler import profile

@profile
def create_list():
    my_list = [i for i in range(100000)]
    return my_list

if __name__ == "__main__":
    create_list()
#python -m memory_profiler script_name.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3150012736.py in <cell line: 0>()
#       1 #16. Demonstrate how to use memory profiling to check the memory usage of a small program ?
#       2 #pip install memory-profiler
# ----> 3 from memory_profiler import profile
#       4
#       5 @profile
#
# ModuleNotFoundError: No module named 'memory_profiler'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %pip install memory-profiler

# %%
#16. Demonstrate how to use memory profiling to check the memory usage of a small program ?
from memory_profiler import profile

@profile
def create_list():
    my_list = [i for i in range(100000)]
    return my_list

if __name__ == "__main__":
    create_list()
#python -m memory_profiler script_name.py
# Out:
# ERROR: Could not find file /tmp/ipython-input-2731871965.py

# %%
#17. Write a Python program to create and write a list of numbers to a file, one number per line.

numbers = [10, 20, 30, 40, 50]
with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(f"{number}\n")
print("Numbers written to 'numbers.txt' successfully.")
# Out:
# Numbers written to 'numbers.txt' successfully.

# %%
#18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

import logging
from logging.handlers import RotatingFileHandler
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.INFO)
handler = RotatingFileHandler(
    "app.log",
    maxBytes=1*1024*1024,
    backupCount=3
)

formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)
logger.addHandler(handler)
for i in range(10000):
    logger.info(f"Logging message number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:MyLogger:Logging message number 5000
# INFO:MyLogger:Logging message number 5001
# INFO:MyLogger:Logging message number 5002
# INFO:MyLogger:Logging message number 5003
# INFO:MyLogger:Logging message number 5004
# INFO:MyLogger:Logging message number 5005
# INFO:MyLogger:Logging message number 5006
# INFO:MyLogger:Logging message number 5007
# INFO:MyLogger:Logging message number 5008
# INFO:MyLogger:Logging message number 5009
# INFO:MyLogger:Logging message number 5010
# INFO:MyLogger:Logging message number 5011
# INFO:MyLogger:Logging message number 5012
# INFO:MyLogger:Logging message number 5013
# INFO:MyLogger:Logging message number 5014
# INFO:MyLogger:Logging message number 5015
# INFO:MyLogger:Logging message number 5016
# INFO:MyLogger:Logging message number 5017
# INFO:MyLogger:Logging message number 5018
# INFO:MyLogger:Logging message number 5019
# INFO:MyLogger:Logging message number 5020
# ...

# %%
#19. Write a program that handles both IndexError and KeyError using a try-except block.

my_list = [10, 20, 30]
my_dict = {"name": "Alice", "age": 25}
try:
    print("List element:", my_list[5])
    print("City:", my_dict["city"])
except IndexError as e:
    print(f"IndexError occurred: {e}")
except KeyError as e:
    print(f"KeyError occurred: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# IndexError occurred: list index out of range

# %%
#20. How would you open a file and read its contents using a context manager in Python.

file_path = "example.txt"

with open(file_path, "r") as file:
    content = file.read()

print("File contents:")
print(content)
# Out:
# File contents:
# Hello, this is a test string.
# Writing another line.This is a new line.
# Appending another line.

# %%
#21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

file_path = "example.txt"
word_to_count = "Python"
try:
    with open(file_path, "r") as file:
        content = file.read()
        words = content.split()
        count = words.count(word_to_count)
    print(f"The word '{word_to_count}' occurs {count} time(s) in the file.")
except FileNotFoundError:
    print(f"Error: The file '{file_path}' does not exist.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# The word 'Python' occurs 0 time(s) in the file.

# %%
#22. How can you check if a file is empty before attempting to read its contents.

import os
file_path = "example.txt"
if os.path.exists(file_path):
    if os.path.getsize(file_path) > 0:
        with open(file_path, "r") as file:
            content = file.read()
            print("File content:")
            print(content)
    else:
        print("The file is empty.")
else:
    print(f"Error: '{file_path}' does not exist.")
# Out:
# Error: 'example.txt' does not exist.

# %%
#23. Write a Python program that writes to a log file when an error occurs during file handling.

import logging
logging.basicConfig(
    filename="file_errors.log",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)
file_path = "example.txt"
try:
    with open(file_path, "r") as file:
        content = file.read()
        print("File content:")
        print(content)
except FileNotFoundError as e:
    logging.error(f"FileNotFoundError: {e}")
    print(f"Error: '{file_path}' does not exist.")
except PermissionError as e:
    logging.error(f"PermissionError: {e}")
    print(f"Error: Permission denied for '{file_path}'.")
except Exception as e:
    logging.error(f"Unexpected error: {e}")
    print("An unexpected error occurred.")
# Out:
# ERROR:root:FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'
# Error: 'example.txt' does not exist.
